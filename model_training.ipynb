# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from imgaug import augmenters as iaa
import random

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow.keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

# %%
def getFileName(filePath):
    return filePath.split('\\')[-1]

# %%
path = 'simulation_data'

# %%
def importData(path):
    columns = ['Center','Left','Right','Steering','Throttle','Brake','Speed']
    data = pd.read_csv(os.path.join(path, 'driving_log.csv'),names = columns)
#     print(data.head())
#     print(data['Center'][0])
#     print(getFileName(data['Center'][0]))
    data['Center'] = data['Center'].apply(getFileName)
    print(data.head())
    print(data.shape[0])
    return data

# %%
data = importData('simulation_data/')
# Out:
#                                Center  \
# 0  center_2021_11_22_23_36_47_786.jpg
# 1  center_2021_11_22_23_36_47_851.jpg
# 2  center_2021_11_22_23_36_47_920.jpg
# 3  center_2021_11_22_23_36_47_987.jpg
# 4  center_2021_11_22_23_36_48_055.jpg
#
#                                                 Left  \
# 0  F:\github\self_driving_car\simulation_data\IMG...
# 1  F:\github\self_driving_car\simulation_data\IMG...
# 2  F:\github\self_driving_car\simulation_data\IMG...
# 3  F:\github\self_driving_car\simulation_data\IMG...
# 4  F:\github\self_driving_car\simulation_data\IMG...
#
#                                                Right  Steering  Throttle  \
# 0  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 1  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 2  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 3  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 4  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
#
#    Brake     Speed
# 0    0.0  0.000007
# 1    0.0  0.000021
# 2    0.0  0.000004
# 3    0.0  0.000022
# 4    0.0  0.000005
# 21063

# %%
data
# Out:
#                                    Center  \
# 0      center_2021_11_22_23_36_47_786.jpg
# 1      center_2021_11_22_23_36_47_851.jpg
# 2      center_2021_11_22_23_36_47_920.jpg
# 3      center_2021_11_22_23_36_47_987.jpg
# 4      center_2021_11_22_23_36_48_055.jpg
# ...                                   ...
# 21058  center_2021_11_23_00_36_34_927.jpg
# 21059  center_2021_11_23_00_36_34_998.jpg
# 21060  center_2021_11_23_00_36_35_072.jpg
# 21061  center_2021_11_23_00_36_35_145.jpg
# 21062  center_2021_11_23_00_36_35_372.jpg
#
#                                                     Left  \
# 0      F:\github\self_driving_car\simulation_data\IMG...
# 1      F:\github\self_driving_car\simulation_data\IMG...
# 2      F:\github\self_driving_car\simulation_data\IMG...
# 3      F:\github\self_driving_car\simulation_data\IMG...
# 4      F:\github\self_driving_car\simulation_data\IMG...
# ...                                                  ...
# 21058  F:\github\self_driving_car\simulation_data\IMG...
# 21059  F:\github\self_driving_car\simulation_data\IMG...
# 21060  F:\github\self_driving_car\simulation_data\IMG...
# 21061  F:\github\self_driving_car\simulation_data\IMG...
# 21062  F:\github\self_driving_car\simulation_data\IMG...
#
#                                                    Right  Steering  Throttle  \
# 0      F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 1      F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 2      F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 3      F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 4      F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# ...                                                  ...       ...       ...
# 21058  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 21059  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 21060  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 21061  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
# 21062  F:\github\self_driving_car\simulation_data\IMG...       0.0       0.0
#
#        Brake     Speed
# 0        0.0  0.000007
# 1        0.0  0.000021
# 2        0.0  0.000004
# 3        0.0  0.000022
# 4        0.0  0.000005
# ...      ...       ...
# 21058    0.0  0.155977
# 21059    0.0  0.156202
# 21060    0.0  0.156501
# 21061    0.0  0.156797
# 21062    0.0  0.157062
#
# [21063 rows x 7 columns]

# %%
def balanceData(data, display=True):
    nBins = 21
    samplesPerBin = 3000
    hist, bins = np.histogram(data['Steering'], nBins)
#     print(bins)
    if display:
        center = (bins[:-1] + bins[1:]) * 0.5
    #     print(center)
        plt.bar(center, hist, width=0.06)
        plt.plot((-1,1),(samplesPerBin, samplesPerBin))
        plt.show()
        
    removeIndexList = []
    for j in range(nBins):
        binDataList = []
        for i in range(len(data['Steering'])):
            if data['Steering'][i] >= bins[j] and data['Steering'][i] <= bins[j+1]:
                binDataList.append(i)
        binDataList = shuffle(binDataList)
        binDataList = binDataList[samplesPerBin:]
        removeIndexList.extend(binDataList)
        
    print("Removed Images: ", len(removeIndexList))
    
    data.drop(data.index[removeIndexList], inplace=True)
    print('Remaining Images: ', len(data))
    
    if display:
        hist, _ = np.histogram(data['Steering'], nBins)
        plt.bar(center, hist, width=0.06)
        plt.plot((-1,1), (samplesPerBin, samplesPerBin))
        plt.show()
        
    return data

# %%
balanced_data = balanceData(data, display=True)
# Out:
# Removed Images:  9354
# Remaining Images:  11709

# %%
def loadData(path, data):
    imagesPath = []
    steering = []
    for i in range(len(data)):
        indexedData = data.iloc[i]
#         print(indexedData)
        imagesPath.append(os.path.join(path, 'IMG', indexedData[0]))
#         print(os.path.join(path, 'IMG', indexedData[0]))
        steering.append(float(indexedData[3]))
        
    imagesPath = np.asarray(imagesPath)
    steering = np.asarray(steering)
    
    return imagesPath, steering

# %%
imagesPath, steerings = loadData(path, balanced_data)

# %%
print(imagesPath[0], steerings[0])
# Out:
# simulation_data\IMG\center_2021_11_22_23_36_47_851.jpg 0.0

# %%
xTrain, xVal, yTrain, yVal = train_test_split(imagesPath, steerings, test_size=0.2, random_state=5)

# %%
print(xTrain.shape)
print(xVal.shape)
print(yTrain.shape)
print(yVal.shape)
# Out:
# (9367,)
# (2342,)
# (9367,)
# (2342,)

# %%
def augmentImage(imagePath, steering):
    img = mpimg.imread(imagePath)
    #pan
    if np.random.rand() < 0.5:
        pan = iaa.Affine(translate_percent={'x':(-0.1,0.1),'y':(-0.1,0.1)})
        img = pan.augment_image(img)
    #zoom
    if np.random.rand() < 0.5:
        zoom = iaa.Affine(scale=(1,1.2))
        img = zoom.augment_image(img)
    #brightness
    if np.random.rand() < 0.5:
        brightness = iaa.Multiply((0.2,1.2))
        img = brightness.augment_image(img)
    #flip
    if np.random.rand() < 0.5:
        img = cv2.flip(img,1)
        steering = -steering
    
    return img, steering

# %%
imgR, stR = augmentImage('test.jpg',0)

# %%
plt.imshow(imgR)
plt.show()

# %%
stR
# Out:
# 0

# %%
def preProcessing(img):
    img = img[65:135,:,:]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
    img = cv2.GaussianBlur(img,(3,3),0)
    img = cv2.resize(img,(200,66))
    img = img/255.0
    return img

# %%
img = mpimg.imread('test.jpg')
print(img.shape)
img_new = preProcessing(img)
plt.imshow(img_new)
plt.show()
# Out:
# (160, 320, 3)

# %%
def batchGen(imgPath, steeringList, batchSize, trainFlag):
    while True:
        imgBatch = []
        steeringBatch = []
        
        for i in range(batchSize):
            index = random.randint(0, len(imgPath)-1)
            if trainFlag:
                img, steering = augmentImage(imgPath[index], steeringList[index])
            else:
                img = mpimg.imread(imgPath[index])
                steering = steeringList[index]
            img = preProcessing(img)
            imgBatch.append(img)
            steeringBatch.append(steering)
        yield(np.asarray(imgBatch), np.asarray(steeringBatch))

# %%
def create_model():
    model = Sequential()
    model.add(Conv2D(24, (5,5), (2,2), input_shape=(66,200,3), activation='elu'))
    model.add(Conv2D(36, (5,5), (2,2), activation='elu'))
    model.add(Conv2D(48, (5,5), (2,2), activation='elu'))
    model.add(Conv2D(64, (3,3), activation='elu'))
    model.add(Conv2D(64, (3,3), activation='elu'))
    
    model.add(Flatten())
    model.add(Dense(100, activation='elu'))
    model.add(Dense(50, activation='elu'))
    model.add(Dense(10, activation='elu'))
    model.add(Dense(1))
    
    return model

# %%
model = create_model()

# %%
model.compile(Adam(learning_rate=0.0001), loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               115300
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 50

# %%
history = model.fit(batchGen(xTrain, yTrain, 100, True), steps_per_epoch=300, epochs=EPOCHS, validation_data=batchGen(xVal, yVal, 100, False), validation_steps=20)
# Out:
# Epoch 1/50
# 300/300 [==============================] - 217s 725ms/step - loss: 0.0122 - val_loss: 0.0091
# Epoch 2/50
# 300/300 [==============================] - 99s 330ms/step - loss: 0.0111 - val_loss: 0.0103
# Epoch 3/50
# 300/300 [==============================] - 77s 258ms/step - loss: 0.0107 - val_loss: 0.0088
# Epoch 4/50
# 300/300 [==============================] - 80s 268ms/step - loss: 0.0106 - val_loss: 0.0069
# Epoch 5/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0102 - val_loss: 0.0099
# Epoch 6/50
# 300/300 [==============================] - 78s 261ms/step - loss: 0.0096 - val_loss: 0.0060
# Epoch 7/50
# 300/300 [==============================] - 80s 266ms/step - loss: 0.0091 - val_loss: 0.0099
# Epoch 8/50
# 300/300 [==============================] - 75s 251ms/step - loss: 0.0087 - val_loss: 0.0097
# Epoch 9/50
# 300/300 [==============================] - 80s 268ms/step - loss: 0.0082 - val_loss: 0.0063
# Epoch 10/50
# 300/300 [==============================] - 75s 249ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 11/50
# 300/300 [==============================] - 75s 252ms/step - loss: 0.0081 - val_loss: 0.0070
# Epoch 12/50
# 300/300 [==============================] - 75s 249ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 13/50
# 300/300 [==============================] - 75s 250ms/step - loss: 0.0072 - val_loss: 0.0049
# Epoch 14/50
# 300/300 [==============================] - 75s 250ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 15/50
# 300/300 [==============================] - 75s 251ms/step - loss: 0.0069 - val_loss: 0.0046
# Epoch 16/50
# 300/300 [==============================] - 75s 249ms/step - loss: 0.0069 - val_loss: 0.0051
# Epoch 17/50
# 300/300 [==============================] - 75s 250ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 18/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 19/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 20/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0067 - val_loss: 0.0043
# Epoch 21/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 22/50
# 300/300 [==============================] - 74s 248ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 23/50
# 300/300 [==============================] - 74s 247ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 24/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 25/50
# 300/300 [==============================] - 75s 250ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 26/50
# 300/300 [==============================] - 75s 249ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 27/50
# 300/300 [==============================] - 74s 248ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 28/50
# 300/300 [==============================] - 74s 247ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 29/50
# 300/300 [==============================] - 74s 249ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 30/50
# 300/300 [==============================] - 75s 249ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 31/50
# 300/300 [==============================] - 75s 249ms/step - loss: 0.0056 - val_loss: 0.0067
# Epoch 32/50
# 300/300 [==============================] - 75s 250ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 33/50
# 300/300 [==============================] - 105s 350ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 34/50
# 300/300 [==============================] - 127s 426ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 35/50
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 36/50
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 37/50
# 300/300 [==============================] - 129s 431ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 38/50
# 300/300 [==============================] - 131s 436ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 39/50
# 300/300 [==============================] - 126s 422ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 40/50
# 300/300 [==============================] - 133s 445ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 41/50
# 300/300 [==============================] - 127s 425ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 42/50
# 300/300 [==============================] - 130s 433ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 43/50
# 300/300 [==============================] - 123s 410ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 44/50
# 300/300 [==============================] - 126s 422ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 45/50
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 46/50
# 300/300 [==============================] - 135s 451ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 47/50
# 300/300 [==============================] - 141s 470ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 48/50
# 300/300 [==============================] - 159s 532ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 49/50
# 300/300 [==============================] - 132s 442ms/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 50/50
# 300/300 [==============================] - 117s 390ms/step - loss: 0.0050 - val_loss: 0.0046

# %%
model.save('model.h5')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title('loss')
plt.xlabel('Epochs')
plt.show()

# %%
import os
import socketio
import eventlet
import numpy as np
from flask import Flask
from tensorflow.keras.models import load_model
import base64
from io import BytesIO
from PIL import Image
import cv2

# %%
#### FOR REAL TIME COMMUNICATION BETWEEN CLIENT AND SERVER
sio = socketio.Server()
#### FLASK IS A MICRO WEB FRAMEWORK WRITTEN IN PYTHON
app = Flask(__name__)  # '__main__'
 
maxSpeed = 10
 
 
def preProcess(img):
    img = img[60:135,:,:]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
    img = cv2.GaussianBlur(img,  (3, 3), 0)
    img = cv2.resize(img, (200, 66))
    img = img/255
    return img
 
 
@sio.on('telemetry')
def telemetry(sid, data):
    speed = float(data['speed'])
    image = Image.open(BytesIO(base64.b64decode(data['image'])))
    image = np.asarray(image)
    image = preProcess(image)
    image = np.array([image])
    steering = float(model.predict(image))
    throttle = 1.0 - speed / maxSpeed
    print(f'{steering}, {throttle}, {speed}')
    sendControl(steering, throttle)
 
 
@sio.on('connect')
def connect(sid, environ):
    print('Connected')
    sendControl(0, 0)
 
 
def sendControl(steering, throttle):
    sio.emit('steer', data={
        'steering_angle': steering.__str__(),
        'throttle': throttle.__str__()
    })
 
 
if __name__ == '__main__':
    model = load_model('model.h5')
    app = socketio.Middleware(sio, app)
    ### LISTEN TO PORT 4567
    eventlet.wsgi.server(eventlet.listen(('', 4567)), app)

# %%
# !python drive.py model.h5
# Out:
# 2022-12-17 18:47:08.501592: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# C:\Users\nkele\.conda\envs\tfgpu\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\nkele\.conda\envs\tfgpu\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\nkele\.conda\envs\tfgpu\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)
# Traceback (most recent call last):
#   File "drive.py", line 15, in <module>
#     from keras.models import load_model
#   File "C:\Users\nkele\.conda\envs\tfgpu\lib\site-packages\keras\__init__.py", line 25, in <module>
#     from keras import models
#   File "C:\Users\nkele\.conda\envs\tfgpu\lib\site-packages\keras\models.py", line 19, in <module>
#     from keras import backend
#   File "C:\Users\nkele\.conda\envs\tfgpu\lib\site-packages\keras\backend.py", line 37, in <module>
#     from tensorflow.python.eager.context import get_config
# ImportError: cannot import name 'get_config' from 'tensorflow.python.eager.context' (C:\Users\nkele\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\context.py)
